# %% [markdown]
# ## 그래프 그리기 전에 세팅할 것들

# %%
import matplotlib as mpl
import matplotlib.pyplot as plt
import seaborn as sns
# %matplotlib inline

# %% [markdown]
# ### 그래프에서 한글이 깨질 경우

# %%
from matplotlib import font_manager, rc

x = font_manager.FontProperties(fname='font.ttf').get_name()
rc('font', family=x)

# %%
import numpy as np
import pandas as pd

# %%
mpl.rcParams['axes.unicode_minus'] = False

# %%
df = pd.DataFrame(np.random.rand(6, 3), columns=['a', 'b', 'c'])
df['d'] = pd.Series([1, 1, 1, 0.5, 0.5, 0.3])

df
# Out:
#           a         b         c    d
# 0  0.422043  0.913187  0.674257  1.0
# 1  0.494373  0.460191  0.364700  1.0
# 2  0.804033  0.477950  0.312793  1.0
# 3  0.603902  0.764126  0.432423  0.5
# 4  0.564212  0.835944  0.930737  0.5
# 5  0.460927  0.131254  0.881361  0.3

# %% [markdown]
# ## 1. 막대 그래프

# %%
df.plot(kind='bar')
# Out:
# <AxesSubplot:>

# %%
df.plot.bar()
# Out:
# <AxesSubplot:>

# %%
df.plot.bar()
plt.legend(loc='best')

# %%
df.plot.bar()
plt.legend(loc='lower right')
plt.xlabel('인덱스 번호')
plt.ylabel('값')
# Out:
# Text(0, 0.5, '값')
# /opt/homebrew/Caskroom/miniforge/base/envs/pandas_info/lib/python3.10/site-packages/IPython/core/pylabtools.py:151: UserWarning: Glyph 51064 (\N{HANGUL SYLLABLE IN}) missing from current font.
#   fig.canvas.print_figure(bytes_io, **kw)
# /opt/homebrew/Caskroom/miniforge/base/envs/pandas_info/lib/python3.10/site-packages/IPython/core/pylabtools.py:151: UserWarning: Glyph 45937 (\N{HANGUL SYLLABLE DEG}) missing from current font.
#   fig.canvas.print_figure(bytes_io, **kw)
# /opt/homebrew/Caskroom/miniforge/base/envs/pandas_info/lib/python3.10/site-packages/IPython/core/pylabtools.py:151: UserWarning: Glyph 49828 (\N{HANGUL SYLLABLE SEU}) missing from current font.
#   fig.canvas.print_figure(bytes_io, **kw)
# /opt/homebrew/Caskroom/miniforge/base/envs/pandas_info/lib/python3.10/site-packages/IPython/core/pylabtools.py:151: UserWarning: Glyph 48264 (\N{HANGUL SYLLABLE BEON}) missing from current font.
#   fig.canvas.print_figure(bytes_io, **kw)
# /opt/homebrew/Caskroom/miniforge/base/envs/pandas_info/lib/python3.10/site-packages/IPython/core/pylabtools.py:151: UserWarning: Glyph 54840 (\N{HANGUL SYLLABLE HO}) missing from current font.
#   fig.canvas.print_figure(bytes_io, **kw)
# /opt/homebrew/Caskroom/miniforge/base/envs/pandas_info/lib/python3.10/site-packages/IPython/core/pylabtools.py:151: UserWarning: Glyph 44050 (\N{HANGUL SYLLABLE GABS}) missing from current font.
#   fig.canvas.print_figure(bytes_io, **kw)

# %%
from matplotlib import font_manager, rc
f_name = font_manager.FontProperties(fname='/Users/isoyeon/Library/Fonts/D2Coding-Ver1.3.2-20180524.ttf').get_name()
rc('font', family=f_name)

f_name
# Out:
# 'D2Coding'

# %%
df.plot.bar()
plt.legend(loc='lower right')
plt.xlabel('인덱스 번호')
plt.ylabel('값')
plt.title('세로 막대 그래프')
# Out:
# Text(0.5, 1.0, '세로 막대 그래프')
# /opt/homebrew/Caskroom/miniforge/base/envs/pandas_info/lib/python3.10/site-packages/IPython/core/pylabtools.py:151: UserWarning: Glyph 49464 (\N{HANGUL SYLLABLE SE}) missing from current font.
#   fig.canvas.print_figure(bytes_io, **kw)
# /opt/homebrew/Caskroom/miniforge/base/envs/pandas_info/lib/python3.10/site-packages/IPython/core/pylabtools.py:151: UserWarning: Glyph 47196 (\N{HANGUL SYLLABLE RO}) missing from current font.
#   fig.canvas.print_figure(bytes_io, **kw)
# /opt/homebrew/Caskroom/miniforge/base/envs/pandas_info/lib/python3.10/site-packages/IPython/core/pylabtools.py:151: UserWarning: Glyph 47561 (\N{HANGUL SYLLABLE MAG}) missing from current font.
#   fig.canvas.print_figure(bytes_io, **kw)
# /opt/homebrew/Caskroom/miniforge/base/envs/pandas_info/lib/python3.10/site-packages/IPython/core/pylabtools.py:151: UserWarning: Glyph 45824 (\N{HANGUL SYLLABLE DAE}) missing from current font.
#   fig.canvas.print_figure(bytes_io, **kw)
# /opt/homebrew/Caskroom/miniforge/base/envs/pandas_info/lib/python3.10/site-packages/IPython/core/pylabtools.py:151: UserWarning: Glyph 44536 (\N{HANGUL SYLLABLE GEU}) missing from current font.
#   fig.canvas.print_figure(bytes_io, **kw)
# /opt/homebrew/Caskroom/miniforge/base/envs/pandas_info/lib/python3.10/site-packages/IPython/core/pylabtools.py:151: UserWarning: Glyph 47000 (\N{HANGUL SYLLABLE RAE}) missing from current font.
#   fig.canvas.print_figure(bytes_io, **kw)
# /opt/homebrew/Caskroom/miniforge/base/envs/pandas_info/lib/python3.10/site-packages/IPython/core/pylabtools.py:151: UserWarning: Glyph 54532 (\N{HANGUL SYLLABLE PEU}) missing from current font.
#   fig.canvas.print_figure(bytes_io, **kw)
# /opt/homebrew/Caskroom/miniforge/base/envs/pandas_info/lib/python3.10/site-packages/IPython/core/pylabtools.py:151: UserWarning: Glyph 51064 (\N{HANGUL SYLLABLE IN}) missing from current font.
#   fig.canvas.print_figure(bytes_io, **kw)
# /opt/homebrew/Caskroom/miniforge/base/envs/pandas_info/lib/python3.10/site-packages/IPython/core/pylabtools.py:151: UserWarning: Glyph 45937 (\N{HANGUL SYLLABLE DEG}) missing from current font.
#   fig.canvas.print_figure(bytes_io, **kw)
# /opt/homebrew/Caskroom/miniforge/base/envs/pandas_info/lib/python3.10/site-packages/IPython/core/pylabtools.py:151: UserWarning: Glyph 49828 (\N{HANGUL SYLLABLE SEU}) missing from current font.
#   fig.canvas.print_figure(bytes_io, **kw)
# /opt/homebrew/Caskroom/miniforge/base/envs/pandas_info/lib/python3.10/site-packages/IPython/core/pylabtools.py:151: UserWarning: Glyph 48264 (\N{HANGUL SYLLABLE BEON}) missing from current font.
#   fig.canvas.print_figure(bytes_io, **kw)
# /opt/homebrew/Caskroom/miniforge/base/envs/pandas_info/lib/python3.10/site-packages/IPython/core/pylabtools.py:151: UserWarning: Glyph 54840 (\N{HANGUL SYLLABLE HO}) missing from current font.
#   fig.canvas.print_figure(bytes_io, **kw)
# /opt/homebrew/Caskroom/miniforge/base/envs/pandas_info/lib/python3.10/site-packages/IPython/core/pylabtools.py:151: UserWarning: Glyph 44050 (\N{HANGUL SYLLABLE GABS}) missing from current font.
#   fig.canvas.print_figure(bytes_io, **kw)

# %%
df
# Out:
#           a         b         c    d
# 0  0.422043  0.913187  0.674257  1.0
# 1  0.494373  0.460191  0.364700  1.0
# 2  0.804033  0.477950  0.312793  1.0
# 3  0.603902  0.764126  0.432423  0.5
# 4  0.564212  0.835944  0.930737  0.5
# 5  0.460927  0.131254  0.881361  0.3

# %%
df.iloc[5].plot(kind='bar')
# Out:
# <AxesSubplot:>

# %%
df.iloc[5].plot.bar()
# Out:
# <AxesSubplot:>

# %%
# 기준선 추가
plt.axhline(0.3, color='k')

# %%
df.iloc[5].plot.bar()
plt.axhline(0.3, color='k')

# %%
df
# Out:
#           a         b         c    d
# 0  0.422043  0.913187  0.674257  1.0
# 1  0.494373  0.460191  0.364700  1.0
# 2  0.804033  0.477950  0.312793  1.0
# 3  0.603902  0.764126  0.432423  0.5
# 4  0.564212  0.835944  0.930737  0.5
# 5  0.460927  0.131254  0.881361  0.3

# %%
sns.countplot(data=df, x='d')
# Out:
# <AxesSubplot:xlabel='d', ylabel='count'>

# %%
sns.barplot(data=df)
# Out:
# <AxesSubplot:>

# %%
df.plot.bar(stacked=True)
# Out:
# <AxesSubplot:>

# %%
df.plot.barh()
# Out:
# <AxesSubplot:>

# %%
df.plot.barh(stacked=True)
# Out:
# <AxesSubplot:>

# %%
import numpy as np
import matplotlib.pyplot as plt
from matplotlib import font_manager, rc

sales_data = np.loadtxt('./../data/se_sales.txt', skiprows=8)
sales_data
# Out:
# array([[2.014e+03, 1.000e+00, 1.132e+01, 3.244e+01, 1.556e+01, 9.390e+00,
#         6.100e+00],
#        [2.014e+03, 2.000e+00, 1.300e+01, 2.845e+01, 1.623e+01, 9.780e+00,
#         6.330e+00],
#        [2.014e+03, 3.000e+00, 1.160e+01, 2.458e+01, 1.629e+01, 9.890e+00,
#         6.250e+00],
#        [2.014e+03, 4.000e+00, 1.427e+01, 2.629e+01, 1.771e+01, 1.066e+01,
#         7.050e+00],
#        [2.015e+03, 1.000e+00, 1.026e+01, 2.589e+01, 1.710e+01, 1.027e+01,
#         6.850e+00],
#        [2.015e+03, 2.000e+00, 1.120e+01, 2.606e+01, 1.787e+01, 1.129e+01,
#         6.620e+00],
#        [2.015e+03, 3.000e+00, 1.159e+01, 2.661e+01, 2.031e+01, 1.282e+01,
#         7.490e+00],
#        [2.015e+03, 4.000e+00, 1.385e+01, 2.500e+01, 1.974e+01, 1.321e+01,
#         6.530e+00],
#        [2.016e+03, 1.000e+00, 1.062e+01, 2.760e+01, 1.718e+01, 1.115e+01,
#         6.040e+00],
#        [2.016e+03, 2.000e+00, 1.155e+01, 2.656e+01, 1.843e+01, 1.200e+01,
#         6.420e+00],
#        [2.016e+03, 3.000e+00, 1.124e+01, 2.254e+01, 2.029e+01, 1.315e+01,
#         7.060e+00],
#        [2.016e+03, 4.000e+00, 1.364e+01, 2.361e+01, 2.226e+01, 1.486e+01,
#         7.420e+00]])

# %%
years = np.arange(2014, 2017)

s_2014 = sales_data[sales_data[:, 0] == 2014][:, 2:].sum(axis=0)
s_2015 = sales_data[sales_data[:, 0] == 2015][:, 2:].sum(axis=0)
s_2016 = sales_data[sales_data[:, 0] == 2016][:, 2:].sum(axis=0)

sales = np.array([s_2014, s_2015, s_2016])

# %%
plt.figure(figsize=(7, 5))
plt.title('삼성전자 년도별 매출액 추이')
plt.xlabel('year')
plt.ylabel('earnings')
plt.xticks(years)
# Out:
# ([<matplotlib.axis.XTick at 0x13fc512d0>,
#   <matplotlib.axis.XTick at 0x13fc523e0>,
#   <matplotlib.axis.XTick at 0x13fc51f30>],
#  [Text(0, 0, ''), Text(0, 0, ''), Text(0, 0, '')])
# /opt/homebrew/Caskroom/miniforge/base/envs/pandas_info/lib/python3.10/site-packages/IPython/core/pylabtools.py:151: UserWarning: Glyph 49340 (\N{HANGUL SYLLABLE SAM}) missing from current font.
#   fig.canvas.print_figure(bytes_io, **kw)
# /opt/homebrew/Caskroom/miniforge/base/envs/pandas_info/lib/python3.10/site-packages/IPython/core/pylabtools.py:151: UserWarning: Glyph 49457 (\N{HANGUL SYLLABLE SEONG}) missing from current font.
#   fig.canvas.print_figure(bytes_io, **kw)
# /opt/homebrew/Caskroom/miniforge/base/envs/pandas_info/lib/python3.10/site-packages/IPython/core/pylabtools.py:151: UserWarning: Glyph 51204 (\N{HANGUL SYLLABLE JEON}) missing from current font.
#   fig.canvas.print_figure(bytes_io, **kw)
# /opt/homebrew/Caskroom/miniforge/base/envs/pandas_info/lib/python3.10/site-packages/IPython/core/pylabtools.py:151: UserWarning: Glyph 51088 (\N{HANGUL SYLLABLE JA}) missing from current font.
#   fig.canvas.print_figure(bytes_io, **kw)
# /opt/homebrew/Caskroom/miniforge/base/envs/pandas_info/lib/python3.10/site-packages/IPython/core/pylabtools.py:151: UserWarning: Glyph 45380 (\N{HANGUL SYLLABLE NYEON}) missing from current font.
#   fig.canvas.print_figure(bytes_io, **kw)
# /opt/homebrew/Caskroom/miniforge/base/envs/pandas_info/lib/python3.10/site-packages/IPython/core/pylabtools.py:151: UserWarning: Glyph 46020 (\N{HANGUL SYLLABLE DO}) missing from current font.
#   fig.canvas.print_figure(bytes_io, **kw)
# /opt/homebrew/Caskroom/miniforge/base/envs/pandas_info/lib/python3.10/site-packages/IPython/core/pylabtools.py:151: UserWarning: Glyph 48324 (\N{HANGUL SYLLABLE BYEOL}) missing from current font.
#   fig.canvas.print_figure(bytes_io, **kw)
# /opt/homebrew/Caskroom/miniforge/base/envs/pandas_info/lib/python3.10/site-packages/IPython/core/pylabtools.py:151: UserWarning: Glyph 47588 (\N{HANGUL SYLLABLE MAE}) missing from current font.
#   fig.canvas.print_figure(bytes_io, **kw)
# /opt/homebrew/Caskroom/miniforge/base/envs/pandas_info/lib/python3.10/site-packages/IPython/core/pylabtools.py:151: UserWarning: Glyph 52636 (\N{HANGUL SYLLABLE CUL}) missing from current font.
#   fig.canvas.print_figure(bytes_io, **kw)
# /opt/homebrew/Caskroom/miniforge/base/envs/pandas_info/lib/python3.10/site-packages/IPython/core/pylabtools.py:151: UserWarning: Glyph 50529 (\N{HANGUL SYLLABLE AEG}) missing from current font.
#   fig.canvas.print_figure(bytes_io, **kw)
# /opt/homebrew/Caskroom/miniforge/base/envs/pandas_info/lib/python3.10/site-packages/IPython/core/pylabtools.py:151: UserWarning: Glyph 52628 (\N{HANGUL SYLLABLE CU}) missing from current font.
#   fig.canvas.print_figure(bytes_io, **kw)
# /opt/homebrew/Caskroom/miniforge/base/envs/pandas_info/lib/python3.10/site-packages/IPython/core/pylabtools.py:151: UserWarning: Glyph 51060 (\N{HANGUL SYLLABLE I}) missing from current font.
#   fig.canvas.print_figure(bytes_io, **kw)

# %%
sd = pd.read_csv('./../data/se_sales.txt', skiprows=7, sep='\t', encoding='utf-8')
sd
# Out:
#       년도  분기     CE     IM     DS     SC    DP
# 0   2014   1  11.32  32.44  15.56   9.39  6.10
# 1   2014   2  13.00  28.45  16.23   9.78  6.33
# 2   2014   3  11.60  24.58  16.29   9.89  6.25
# 3   2014   4  14.27  26.29  17.71  10.66  7.05
# 4   2015   1  10.26  25.89  17.10  10.27  6.85
# 5   2015   2  11.20  26.06  17.87  11.29  6.62
# 6   2015   3  11.59  26.61  20.31  12.82  7.49
# 7   2015   4  13.85  25.00  19.74  13.21  6.53
# 8   2016   1  10.62  27.60  17.18  11.15  6.04
# 9   2016   2  11.55  26.56  18.43  12.00  6.42
# 10  2016   3  11.24  22.54  20.29  13.15  7.06
# 11  2016   4  13.64  23.61  22.26  14.86  7.42

# %%
sd.dtypes
# Out:
# 년도      int64
# 분기      int64
# CE    float64
# IM    float64
# DS    float64
# SC    float64
# DP    float64
# dtype: object

# %%
sd = pd.read_csv('./../data/se_sales.txt', skiprows=7, index_col=['년도'], sep='\t', encoding='utf-8')
sd
# Out:
#       분기     CE     IM     DS     SC    DP
# 년도
# 2014   1  11.32  32.44  15.56   9.39  6.10
# 2014   2  13.00  28.45  16.23   9.78  6.33
# 2014   3  11.60  24.58  16.29   9.89  6.25
# 2014   4  14.27  26.29  17.71  10.66  7.05
# 2015   1  10.26  25.89  17.10  10.27  6.85
# 2015   2  11.20  26.06  17.87  11.29  6.62
# 2015   3  11.59  26.61  20.31  12.82  7.49
# 2015   4  13.85  25.00  19.74  13.21  6.53
# 2016   1  10.62  27.60  17.18  11.15  6.04
# 2016   2  11.55  26.56  18.43  12.00  6.42
# 2016   3  11.24  22.54  20.29  13.15  7.06
# 2016   4  13.64  23.61  22.26  14.86  7.42

# %%
sd_g = sd.groupby('년도').sum()
sd_g
# Out:
#       분기     CE      IM     DS     SC     DP
# 년도
# 2014  10  50.19  111.76  65.79  39.72  25.73
# 2015  10  46.90  103.56  75.02  47.59  27.49
# 2016  10  47.05  100.31  78.16  51.16  26.94

# %%
sd_g2 = sd_g.drop(columns='분기')
sd_g2
# Out:
#          CE      IM     DS     SC     DP
# 년도
# 2014  50.19  111.76  65.79  39.72  25.73
# 2015  46.90  103.56  75.02  47.59  27.49
# 2016  47.05  100.31  78.16  51.16  26.94

# %%
sd_g2.plot.bar(stacked=True, color=['r', 'g', 'b', 'y', 'brown'])
plt.legend(loc='upper right')
plt.title('earnings')
plt.ylabel('total')
# Out:
# Text(0, 0.5, 'total')
# /opt/homebrew/Caskroom/miniforge/base/envs/pandas_info/lib/python3.10/site-packages/IPython/core/pylabtools.py:151: UserWarning: Glyph 45380 (\N{HANGUL SYLLABLE NYEON}) missing from current font.
#   fig.canvas.print_figure(bytes_io, **kw)
# /opt/homebrew/Caskroom/miniforge/base/envs/pandas_info/lib/python3.10/site-packages/IPython/core/pylabtools.py:151: UserWarning: Glyph 46020 (\N{HANGUL SYLLABLE DO}) missing from current font.
#   fig.canvas.print_figure(bytes_io, **kw)

# %% [markdown]
# ## 2. 선그래프

# %%
df
# Out:
#           a         b         c    d
# 0  0.422043  0.913187  0.674257  1.0
# 1  0.494373  0.460191  0.364700  1.0
# 2  0.804033  0.477950  0.312793  1.0
# 3  0.603902  0.764126  0.432423  0.5
# 4  0.564212  0.835944  0.930737  0.5
# 5  0.460927  0.131254  0.881361  0.3

# %%
df.plot()
# Out:
# <AxesSubplot:>

# %%
df.plot.line()
# Out:
# <AxesSubplot:>

# %%
plt.plot(df)
# Out:
# [<matplotlib.lines.Line2D at 0x16080f370>,
#  <matplotlib.lines.Line2D at 0x16080f3d0>,
#  <matplotlib.lines.Line2D at 0x16080f4f0>,
#  <matplotlib.lines.Line2D at 0x16080f610>]

# %%
sns.lineplot(data=df)
# Out:
# <AxesSubplot:>

# %%
df.plot(marker='s', linestyle='dashed', linewidth=3, markersize=12)
# Out:
# <AxesSubplot:>

# %%
plt.plot(df, 's--', linewidth=3, markersize=12)
# Out:
# [<matplotlib.lines.Line2D at 0x1609707c0>,
#  <matplotlib.lines.Line2D at 0x1609708b0>,
#  <matplotlib.lines.Line2D at 0x1609709d0>,
#  <matplotlib.lines.Line2D at 0x160970af0>]

# %%
sns.lineplot(data=df, marker='s', linewidth=3, markersize=12)
# Out:
# <AxesSubplot:>

# %%
sns.pointplot(data=df)
# Out:
# <AxesSubplot:>

# %%
df2 = df.cumsum()
df2.plot()
# Out:
# <AxesSubplot:>

# %%
df.plot.area()
# Out:
# <AxesSubplot:>

# %%
df.plot(stacked=False)
# Out:
# <AxesSubplot:>

# %%
df.plot()
# Out:
# <AxesSubplot:>

# %% [markdown]
# ### 3. 히스토그램

# %%
df.plot.hist()
# Out:
# <AxesSubplot:ylabel='Frequency'>

# %%
df.plot.hist(alpha=0.5)
# Out:
# <AxesSubplot:ylabel='Frequency'>

# %%
df.plot.hist(bins=20)
# Out:
# <AxesSubplot:ylabel='Frequency'>

# %%
df.plot.hist(orientation='horizontal')
# Out:
# <AxesSubplot:xlabel='Frequency'>

# %%
df.plot.hist(cumulative=True, orientation='horizontal')
# Out:
# <AxesSubplot:xlabel='Frequency'>

# %%
df.plot.density()
# Out:
# <AxesSubplot:ylabel='Density'>

# %%
df.plot.kde()
# Out:
# <AxesSubplot:ylabel='Density'>

# %%
df.boxplot(grid=True)
# Out:
# <AxesSubplot:>

# %%
df.boxplot(vert=False)
# Out:
# <AxesSubplot:>

# %%
df.boxplot(grid=True)
# Out:
# <AxesSubplot:>

# %%
df.plot.pie(figsize=(6,6))
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# /var/folders/_p/x_57820s1b15kl1dk8sw72kc0000gn/T/ipykernel_17850/232451899.py in <module>
# ----> 1 df.plot.pie(figsize=(6,6))
#
# /opt/homebrew/Caskroom/miniforge/base/envs/pandas_info/lib/python3.10/site-packages/pandas/plotting/_core.py in pie(self, **kwargs)
#    1548             and not kwargs.get("subplots", False)
#    1549         ):
# -> 1550             raise ValueError("pie requires either y column or 'subplots=True'")
#    1551         return self(kind="pie", **kwargs)
#    1552
#
# ValueError: pie requires either y column or 'subplots=True'

# %% [markdown]
# ## 6. 산포도

# %%
df.plot.hexbin(x='a', y='b', gridsize=35)
# Out:
# <AxesSubplot:xlabel='a', ylabel='b'>
